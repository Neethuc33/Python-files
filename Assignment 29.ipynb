# %%
import os 
import numpy as np 
import pandas as pd

# %%
os.chdir ('C:\\Users\\LENOVO\\Desktop\\My File\\')
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\Desktop\\My File'

# %%
print (os.getcwd()  )
# Out:
# C:\Users\LENOVO\Desktop\My File

# %%
dataset = pd.read_excel('Health_Score.xlsx')
display (dataset)
# Out:
#     Birth Rate  No of Hospitlas  No of Doctors  Annual Income  \
# 0          8.0               78            284            9.1
# 1          9.3               68            433            8.7
# 2          7.5               70            739            7.2
# 3          8.9               96           1792            8.9
# 4         10.2               74            477            8.3
# 5          8.3              111            362           10.9
# 6          8.8               77            671           10.0
# 7          8.8              168            636            9.1
# 8         10.7               82            329            8.7
# 9         11.7               89            634            7.6
# 10         8.5              149            631           10.8
# 11         8.3               60            257            9.5
# 12         8.2               96            284            8.8
# 13         7.9               83            603            9.5
# 14        10.3              130            686            8.7
# 15         7.4              145            345           11.2
# 16         9.6              112           1357            9.7
# 17         9.3              131            544            9.6
# 18        10.6               80            205            9.1
# 19         9.7              130           1264            9.2
# 20        11.6              140            688            8.3
# 21         8.1              154            354            8.4
# 22         9.8              118           1632            9.4
# 23         7.4               94            348            9.8
# 24         9.4              119            370           10.4
# 25        11.2              153            648            9.9
# 26         9.1              116            366            9.2
# 27        10.5               97            540           10.3
# 28        11.9              176            680            8.9
# 29         8.4               75            345            9.6
# 30         5.0              134            525           10.3
# 31         9.8              161            870           10.4
# 32         9.8              111            669            9.7
# 33        10.8              114            452            9.6
# 34        10.1              142            430           10.7
# 35        10.9              238            822           10.3
# 36         9.2               78            190           10.7
# 37         8.3              196            867            9.6
# 38         7.3              125            969           10.5
# 39         9.4               82            499            7.7
# 40         9.4              125            925           10.2
# 41         9.8              129            353            9.9
# 42         3.6               84            288            8.4
# 43         8.4              183            718           10.4
# 44        10.8              119            540            9.2
# 45        10.1              180            668           13.0
# 46         9.0               82            347            8.8
# 47        10.0               71            345            9.2
# 48        11.3              118            463            7.8
# 49        11.3              121            728            8.2
# 50        12.8               68            383            7.4
# 51        10.0              112            316           10.4
# 52         6.7              109            388            8.9
#
#     Population Density
# 0                  109
# 1                  144
# 2                  113
# 3                   97
# 4                  206
# 5                  124
# 6                  152
# 7                  162
# 8                  150
# 9                  134
# 10                 292
# 11                 108
# 12                 111
# 13                 182
# 14                 129
# 15                 158
# 16                 186
# 17                 177
# 18                 127
# 19                 179
# 20                  80
# 21                 103
# 22                 101
# 23                 117
# 24                  88
# 25                  78
# 26                 102
# 27                  95
# 28                  80
# 29                  92
# 30                 126
# 31                 108
# 32                  77
# 33                  60
# 34                  71
# 35                  86
# 36                  93
# 37                 106
# 38                 162
# 39                  95
# 40                  91
# 41                  52
# 42                 110
# 43                  69
# 44                  57
# 45                 106
# 46                  40
# 47                  50
# 48                  35
# 49                  86
# 50                  57
# 51                  57
# 52                  94

# %%
x = dataset.iloc[:,1:].values
display (x)
# Out:
# array([[  78.        ,  284.        ,    9.10000038,  109.        ],
#        [ 109.        ,  388.        ,    8.89999962,   94.        ]])

# %%
y = dataset.iloc[:,0].values
display (y)
# Out:
# array([ 8.        ,  9.30000019,  7.5       ,  8.89999962, 10.19999981,
#         8.30000019,  8.80000019,  8.80000019, 10.69999981, 11.69999981,
#         8.5       ,  8.30000019,  8.19999981,  7.9000001 , 10.30000019,
#         7.4000001 ,  9.60000038,  9.30000019, 10.60000038,  9.69999981,
#        11.60000038,  8.10000038,  9.80000019,  7.4000001 ,  9.39999962,
#        11.19999981,  9.10000038, 10.5       , 11.89999962,  8.39999962,
#         5.        ,  9.80000019,  9.80000019, 10.80000019, 10.10000038,
#        10.89999962,  9.19999981,  8.30000019,  7.30000019,  9.39999962,
#         9.39999962,  9.80000019,  3.5999999 ,  8.39999962, 10.80000019,
#        10.10000038,  9.        , 10.        , 11.30000019, 11.30000019,
#        12.80000019, 10.        ,  6.69999981])

# %%
print (dataset.shape)

print (x.shape)

print (y.shape)
# Out:
# (53, 5)
# (53, 4)
# (53,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

print (x.shape)
print (x_train.shape)
print (x_test.shape)
print (y.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (53, 4)
# (42, 4)
# (11, 4)
# (53,)
# (42,)
# (11,)

# %%
from sklearn.linear_model import LinearRegression
regressor =  LinearRegression()
regressor.fit (x_train, y_train)
print (regressor)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict (x_test )
print (y_pred)
# Out:
# [ 8.65654845 10.57049948  9.12926103  9.56518501  9.15397193 10.19763099
#   9.00579912 10.3654805   7.50633246  9.20384247  6.60848831]

# %%
print (y_test)
# Out:
# [ 5.          7.5        10.          9.80000019  9.80000019  9.
#  10.10000038  9.39999962 10.10000038  9.69999981  8.5       ]

# %%
df_y_test= pd.DataFrame(y_test, columns = ['Birth Rate'])
df_y_test_pred =  pd.DataFrame(y_pred, columns = ['Prediction'])
df_diff =df_y_test- df_y_test_pred
y_test_pred = pd.concat ([df_y_test, df_y_test_pred ],axis =1)
y_test_pred['Difference'] =df_y_test ['Birth Rate']- df_y_test_pred['Prediction']
print (y_test_pred)
# Out:
#     Birth Rate  Prediction  Difference
# 0          5.0    8.656548   -3.656548
# 1          7.5   10.570499   -3.070499
# 2         10.0    9.129261    0.870739
# 3          9.8    9.565185    0.234815
# 4          9.8    9.153972    0.646028
# 5          9.0   10.197631   -1.197631
# 6         10.1    9.005799    1.094201
# 7          9.4   10.365480   -0.965481
# 8         10.1    7.506332    2.593668
# 9          9.7    9.203842    0.496157
# 10         8.5    6.608488    1.891512

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test,y_pred)
print (accuracy)
# Out:
# -0.599383373530775

# %%
y_pred = regressor.predict (x )
print (y_pred)
# Out:
# [ 9.16830283  9.06981045 10.57049948 10.48822982  8.67884787  8.08173424
#   8.35938875  9.24621142  9.00537556 10.10924015  6.60848831  8.82039276
#   9.4246574   8.32121054  9.71259243  7.66810144  8.77961834  8.51753078
#   8.92410509  9.20384247 10.56963221 10.10241672 10.13597454  8.75874067
#   8.84854448  9.62508144  9.42764107  8.83119857 10.3674476   9.07005095
#   8.65654845  9.15397193  9.56518501  9.69600677  9.00579912  9.82073492
#   8.2822002   9.85340539  8.36367688 10.3654805   9.32686798  9.60932803
#   9.63004436  9.60756789 10.06314535  7.50633246 10.19763099  9.77649655
#  11.13822764 10.49516297 10.83918806  9.12926103  9.68587003]

# %%
print (y)
# Out:
# [ 8.          9.30000019  7.5         8.89999962 10.19999981  8.30000019
#   8.80000019  8.80000019 10.69999981 11.69999981  8.5         8.30000019
#   8.19999981  7.9000001  10.30000019  7.4000001   9.60000038  9.30000019
#  10.60000038  9.69999981 11.60000038  8.10000038  9.80000019  7.4000001
#   9.39999962 11.19999981  9.10000038 10.5        11.89999962  8.39999962
#   5.          9.80000019  9.80000019 10.80000019 10.10000038 10.89999962
#   9.19999981  8.30000019  7.30000019  9.39999962  9.39999962  9.80000019
#   3.5999999   8.39999962 10.80000019 10.10000038  9.         10.
#  11.30000019 11.30000019 12.80000019 10.          6.69999981]

# %%
y_pred = pd.DataFrame(y_pred,columns= ['Prediction'])
final = pd.concat([dataset,y_pred], axis =1)
final['Difference'] =final['Birth Rate']- final['Prediction']
display(final)
# Out:
#     Birth Rate  No of Hospitlas  No of Doctors  Annual Income  \
# 0          8.0               78            284            9.1
# 1          9.3               68            433            8.7
# 2          7.5               70            739            7.2
# 3          8.9               96           1792            8.9
# 4         10.2               74            477            8.3
# 5          8.3              111            362           10.9
# 6          8.8               77            671           10.0
# 7          8.8              168            636            9.1
# 8         10.7               82            329            8.7
# 9         11.7               89            634            7.6
# 10         8.5              149            631           10.8
# 11         8.3               60            257            9.5
# 12         8.2               96            284            8.8
# 13         7.9               83            603            9.5
# 14        10.3              130            686            8.7
# 15         7.4              145            345           11.2
# 16         9.6              112           1357            9.7
# 17         9.3              131            544            9.6
# 18        10.6               80            205            9.1
# 19         9.7              130           1264            9.2
# 20        11.6              140            688            8.3
# 21         8.1              154            354            8.4
# 22         9.8              118           1632            9.4
# 23         7.4               94            348            9.8
# 24         9.4              119            370           10.4
# 25        11.2              153            648            9.9
# 26         9.1              116            366            9.2
# 27        10.5               97            540           10.3
# 28        11.9              176            680            8.9
# 29         8.4               75            345            9.6
# 30         5.0              134            525           10.3
# 31         9.8              161            870           10.4
# 32         9.8              111            669            9.7
# 33        10.8              114            452            9.6
# 34        10.1              142            430           10.7
# 35        10.9              238            822           10.3
# 36         9.2               78            190           10.7
# 37         8.3              196            867            9.6
# 38         7.3              125            969           10.5
# 39         9.4               82            499            7.7
# 40         9.4              125            925           10.2
# 41         9.8              129            353            9.9
# 42         3.6               84            288            8.4
# 43         8.4              183            718           10.4
# 44        10.8              119            540            9.2
# 45        10.1              180            668           13.0
# 46         9.0               82            347            8.8
# 47        10.0               71            345            9.2
# 48        11.3              118            463            7.8
# 49        11.3              121            728            8.2
# 50        12.8               68            383            7.4
# 51        10.0              112            316           10.4
# 52         6.7              109            388            8.9
#
#     Population Density  Prediction  Difference
# 0                  109    9.168303   -1.168303
# 1                  144    9.069810    0.230190
# 2                  113   10.570499   -3.070499
# 3                   97   10.488230   -1.588230
# 4                  206    8.678848    1.521152
# 5                  124    8.081734    0.218266
# 6                  152    8.359389    0.440611
# 7                  162    9.246211   -0.446211
# 8                  150    9.005376    1.694624
# 9                  134   10.109240    1.590760
# 10                 292    6.608488    1.891512
# 11                 108    8.820393   -0.520393
# 12                 111    9.424657   -1.224658
# 13                 182    8.321211   -0.421210
# 14                 129    9.712592    0.587408
# 15                 158    7.668101   -0.268101
# 16                 186    8.779618    0.820382
# 17                 177    8.517531    0.782469
# 18                 127    8.924105    1.675895
# 19                 179    9.203842    0.496157
# 20                  80   10.569632    1.030368
# 21                 103   10.102417   -2.002416
# 22                 101   10.135975   -0.335974
# 23                 117    8.758741   -1.358741
# 24                  88    8.848544    0.551455
# 25                  78    9.625081    1.574918
# 26                 102    9.427641   -0.327641
# 27                  95    8.831199    1.668801
# 28                  80   10.367448    1.532552
# 29                  92    9.070051   -0.670051
# 30                 126    8.656548   -3.656548
# 31                 108    9.153972    0.646028
# 32                  77    9.565185    0.234815
# 33                  60    9.696007    1.103993
# 34                  71    9.005799    1.094201
# 35                  86    9.820735    1.079265
# 36                  93    8.282200    0.917800
# 37                 106    9.853405   -1.553405
# 38                 162    8.363677   -1.063677
# 39                  95   10.365480   -0.965481
# 40                  91    9.326868    0.073132
# 41                  52    9.609328    0.190672
# 42                 110    9.630044   -6.030044
# 43                  69    9.607568   -1.207568
# 44                  57   10.063145    0.736855
# 45                 106    7.506332    2.593668
# 46                  40   10.197631   -1.197631
# 47                  50    9.776497    0.223503
# 48                  35   11.138228    0.161773
# 49                  86   10.495163    0.804837
# 50                  57   10.839188    1.960812
# 51                  57    9.129261    0.870739
# 52                  94    9.685870   -2.985870

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y,y_pred)
print (accuracy)
# Out:
# 0.08950585813004241

# %%
print (regressor.coef_)
# Out:
# [ 0.00501226  0.00064205 -0.62914983 -0.01130558]

# %%
print (regressor.intercept_)
# Out:
# 15.552576766444286

# %%
import statsmodels.api as sm
reg_ols = sm.OLS (endog = y, exog = x)
reg_ols = reg_ols.fit()
print (reg_ols.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.954
# Model:                            OLS   Adj. R-squared (uncentered):              0.950
# Method:                 Least Squares   F-statistic:                              254.2
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):                    4.15e-32
# Time:                        10:21:54   Log-Likelihood:                         -112.63
# No. Observations:                  53   AIC:                                      233.3
# Df Residuals:                      49   BIC:                                      241.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0017      0.009      0.184      0.855      -0.017       0.020
# x2             0.0014      0.001      1.486      0.144      -0.000       0.003
# x3             0.9456      0.137      6.892      0.000       0.670       1.221
# x4            -0.0070      0.006     -1.091      0.281      -0.020       0.006
# ==============================================================================
# Omnibus:                        1.186   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.553   Jarque-Bera (JB):                0.537
# Skew:                           0.185   Prob(JB):                        0.765
# Kurtosis:                       3.325   Cond. No.                         328.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
